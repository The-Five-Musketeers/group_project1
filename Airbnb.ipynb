# %%
# Import the required libraries and dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
airbnb_df1 = pd.read_csv(
    "Resources/01_24_listings.csv",
    # index_col='id', 
    # parse_dates=True
)

airbnb_df2 = pd.read_csv(
    "Resources/02_24_listings.csv",
    # index_col='id', 
    # parse_dates=True
)

airbnb_df3 = pd.read_csv(
    "Resources/03_24_listings.csv",
    # index_col='id', 
    # parse_dates=True
)

airbnb_df4 = pd.read_csv(
    "Resources/04_24_listings.csv",
    # index_col='id', 
    # parse_dates=True
)

airbnb_df6 = pd.read_csv(
    "Resources/6_23_listings.csv",
    # index_col='id', 
    # parse_dates=True
)

airbnb_df7 = pd.read_csv(
    "Resources/7_23_listings.csv",
    # index_col='id', 
    # parse_dates=True
)

airbnb_df8 = pd.read_csv(
    "Resources/8_23_listings.csv",
    # index_col='id', 
    # parse_dates=True
)

airbnb_df9 = pd.read_csv(
    "Resources/9_23_listings.csv",
    # index_col='id', 
    # parse_dates=True
)

airbnb_df10 = pd.read_csv(
    "Resources/10_23_listings.csv",
    # index_col='id', 
    # parse_dates=True
)

airbnb_df11 = pd.read_csv(
    "Resources/11_23_listings.csv",
    # index_col='id', 
    # parse_dates=True
)

airbnb_df12 = pd.read_csv(
    "Resources/12_23_listings.csv",
    # index_col='id', 
    # parse_dates=True
)

# Display the first and last five rows of the DataFrame
airbnb_df1.head()
# Out:
#                    id                                      listing_url  \
# 0            21935608            https://www.airbnb.com/rooms/21935608
# 1  743430766348459803  https://www.airbnb.com/rooms/743430766348459803
# 2             4539906             https://www.airbnb.com/rooms/4539906
# 3            22122723            https://www.airbnb.com/rooms/22122723
# 4            22434861            https://www.airbnb.com/rooms/22434861
#
#         scrape_id last_scraped           source  \
# 0  20240105143223   2024-01-05  previous scrape
# 1  20240105143223   2024-01-05  previous scrape
# 2  20240105143223   2024-01-06  previous scrape
# 3  20240105143223   2024-01-05  previous scrape
# 4  20240105143223   2024-01-05  previous scrape
#
#                                                 name  description  \
# 0  Rental unit in New York · ★4.67 · 1 bedroom · ...          NaN
# 1  Rental unit in Brooklyn · 1 bedroom · 1 bed · ...          NaN
# ...

# %%
#Identify colums within dataframe
airbnb_df1.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
#identify column types within dataframe
airbnb_df1.dtypes
# Out:
# id                                                int64
# listing_url                                      object
# scrape_id                                         int64
# last_scraped                                     object
# source                                           object
#                                                  ...
# calculated_host_listings_count                    int64
# calculated_host_listings_count_entire_homes       int64
# calculated_host_listings_count_private_rooms      int64
# calculated_host_listings_count_shared_rooms       int64
# reviews_per_month                               float64
# Length: 75, dtype: object

# %%
combined_data = pd.concat([airbnb_df1, 
                           airbnb_df2, 
                           airbnb_df3, 
                           airbnb_df4, 
                           airbnb_df6, 
                           airbnb_df7, 
                           airbnb_df8, 
                           airbnb_df9, 
                           airbnb_df10, 
                           airbnb_df11,
                           airbnb_df12], axis=0)

combined_data.head()
# Out:
#              id                                      listing_url  \
# 0  2.193561e+07            https://www.airbnb.com/rooms/21935608
# 1  7.434308e+17  https://www.airbnb.com/rooms/743430766348459803
# 2  4.539906e+06             https://www.airbnb.com/rooms/4539906
# 3  2.212272e+07            https://www.airbnb.com/rooms/22122723
# 4  2.243486e+07            https://www.airbnb.com/rooms/22434861
#
#       scrape_id last_scraped           source  \
# 0  2.024011e+13   2024-01-05  previous scrape
# 1  2.024011e+13   2024-01-05  previous scrape
# 2  2.024011e+13   2024-01-06  previous scrape
# 3  2.024011e+13   2024-01-05  previous scrape
# 4  2.024011e+13   2024-01-05  previous scrape
#
#                                                 name description  \
# 0  Rental unit in New York · ★4.67 · 1 bedroom · ...         NaN
# 1  Rental unit in Brooklyn · 1 bedroom · 1 bed · ...         NaN
# 2  Rental unit in New York · 1 bedroom · 1 bed · ...         NaN
# ...

# %%
print(combined_data.isnull().sum())
# Out:
# id                                                   0
# listing_url                                          0
# scrape_id                                            0
# last_scraped                                         0
# source                                               0
#                                                  ...
# calculated_host_listings_count                       0
# calculated_host_listings_count_entire_homes          0
# calculated_host_listings_count_private_rooms         0
# calculated_host_listings_count_shared_rooms          0
# reviews_per_month                               121077
# Length: 75, dtype: int64

# %%
combined_data.shape
# Out:
# (444526, 75)

# %%
combined_data.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
combined_data.dtypes
# Out:
# id                                              float64
# listing_url                                      object
# scrape_id                                       float64
# last_scraped                                     object
# source                                           object
#                                                  ...
# calculated_host_listings_count                    int64
# calculated_host_listings_count_entire_homes       int64
# calculated_host_listings_count_private_rooms      int64
# calculated_host_listings_count_shared_rooms       int64
# reviews_per_month                               float64
# Length: 75, dtype: object

# %%
combined_data_df = combined_data.loc[:,['id', 
                                       'last_scraped', 
                                       'host_id',
                                       'host_since',
                                       'host_listings_count',
                                       'neighbourhood_cleansed',
                                       'neighbourhood_group_cleansed',
                                       'latitude',
                                       'longitude',
                                       'property_type',
                                       'room_type',
                                       'accommodates',
                                       'price',
                                       'number_of_reviews',
                                       'number_of_reviews_l30d']]

combined_data_df.head()
# Out:
#              id last_scraped   host_id  host_since  host_listings_count  \
# 0  2.193561e+07   2024-01-05   5448955  2013-03-13                  1.0
# 1  7.434308e+17   2024-01-05  83422715  2016-07-12                  1.0
# 2  4.539906e+06   2024-01-06  23540800  2014-11-09                  1.0
# 3  2.212272e+07   2024-01-05  43719554  2015-09-08                  1.0
# 4  2.243486e+07   2024-01-05   5925222  2013-04-14                  1.0
#
#   neighbourhood_cleansed neighbourhood_group_cleansed  latitude  longitude  \
# 0           East Village                    Manhattan  40.73179  -73.98679
# 1               Flatbush                     Brooklyn  40.65375  -73.95502
# 2         Hell's Kitchen                    Manhattan  40.75378  -73.99633
# 3                 Harlem                    Manhattan  40.82440  -73.94598
# 4               Bushwick                     Brooklyn  40.69020  -73.91782
#
#                  property_type        room_type  accommodates    price  \
# ...

# %%
combined_data_df.shape
# Out:
# (444526, 15)

# %%
print(combined_data_df.isnull().sum())
# Out:
# id                                  0
# last_scraped                        0
# host_id                             0
# host_since                         66
# host_listings_count                66
# neighbourhood_cleansed              0
# neighbourhood_group_cleansed        0
# latitude                            0
# longitude                           0
# property_type                       0
# room_type                           0
# accommodates                        0
# price                           55221
# number_of_reviews                   0
# number_of_reviews_l30d              0
# dtype: int64

# %%
clean_combined_data = combined_data_df.dropna()
clean_combined_data.head()
# Out:
#               id last_scraped   host_id  host_since  host_listings_count  \
# 1   7.434308e+17   2024-01-05  83422715  2016-07-12                  1.0
# 9   1.194300e+04   2024-01-05     45445  2009-10-12                  1.0
# 11  1.312228e+06   2024-01-05   7130382  2013-06-26                  1.0
# 23  1.344048e+07   2024-01-06  17385374  2014-06-29                  1.0
# 29  4.527754e+07   2024-01-05  51501835  2015-12-16                139.0
#
#    neighbourhood_cleansed neighbourhood_group_cleansed  latitude  longitude  \
# 1                Flatbush                     Brooklyn  40.65375  -73.95502
# 9                Flatbush                     Brooklyn  40.63702  -73.96327
# 11           Clinton Hill                     Brooklyn  40.68371  -73.96461
# 23        Upper East Side                    Manhattan  40.76550  -73.97080
# 29         Hell's Kitchen                    Manhattan  40.76661  -73.98810
#
# ...

# %%
print(clean_combined_data.isnull().sum())
# Out:
# id                              0
# last_scraped                    0
# host_id                         0
# host_since                      0
# host_listings_count             0
# neighbourhood_cleansed          0
# neighbourhood_group_cleansed    0
# latitude                        0
# longitude                       0
# property_type                   0
# room_type                       0
# accommodates                    0
# price                           0
# number_of_reviews               0
# number_of_reviews_l30d          0
# dtype: int64

# %%
clean_combined_data.shape
# Out:
# (389259, 15)

# %%
clean_combined_data.to_csv('cleaned_data.csv', index = False)

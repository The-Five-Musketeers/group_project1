# %%
# Import the required libraries and dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('cleaned_data.csv')

# %%
df.dtypes
# Out:
# id                              float64
# last_scraped                     object
# host_id                           int64
# host_since                       object
# host_listings_count             float64
# neighbourhood_cleansed           object
# neighbourhood_group_cleansed     object
# latitude                        float64
# longitude                       float64
# property_type                    object
# room_type                        object
# accommodates                      int64
# price                            object
# number_of_reviews                 int64
# number_of_reviews_l30d            int64
# availability_30                   int64
# availability_60                   int64
# dtype: object

# %%
df
# Out:
#                   id last_scraped    host_id  host_since  host_listings_count  \
# 0       7.434308e+17   2024-01-05   83422715  2016-07-12                  1.0
# 1       1.194300e+04   2024-01-05      45445  2009-10-12                  1.0
# 2       1.312228e+06   2024-01-05    7130382  2013-06-26                  1.0
# 3       1.344048e+07   2024-01-06   17385374  2014-06-29                  1.0
# 4       4.527754e+07   2024-01-05   51501835  2015-12-16                139.0
# ...              ...          ...        ...         ...                  ...
# 389254  1.036495e+18   2023-12-04    4134337  2012-11-12                  3.0
# 389255  1.036510e+18   2023-12-04    3030031  2012-07-23                  2.0
# 389256  1.036517e+18   2023-12-04  172103271  2018-02-07                  4.0
# 389257  1.036538e+18   2023-12-04  433720268  2021-11-27                  2.0
# 389258  1.036569e+18   2023-12-04  137358866  2017-06-27                133.0
#
#        neighbourhood_cleansed neighbourhood_group_cleansed   latitude  \
# 0                    Flatbush                     Brooklyn  40.653750
# 1                    Flatbush                     Brooklyn  40.637020
# 2                Clinton Hill                     Brooklyn  40.683710
# 3             Upper East Side                    Manhattan  40.765500
# 4              Hell's Kitchen                    Manhattan  40.766610
# ...                       ...                          ...        ...
# 389254           Williamsburg                     Brooklyn  40.716000
# 389255               Bushwick                     Brooklyn  40.706430
# 389256            Sunset Park                     Brooklyn  40.646402
# 389257     Financial District                    Manhattan  40.707470
# 389258               Woodside                       Queens  40.743172
#
#         longitude                property_type        room_type  accommodates  \
# 0      -73.955020           Entire rental unit  Entire home/apt             3
# 1      -73.963270         Private room in home     Private room             1
# 2      -73.964610  Private room in rental unit     Private room             1
# 3      -73.970800  Private room in rental unit     Private room             1
# 4      -73.988100           Entire rental unit  Entire home/apt             4
# ...           ...                          ...              ...           ...
# 389254 -73.942120           Entire rental unit  Entire home/apt             3
# 389255 -73.919442    Entire serviced apartment  Entire home/apt             2
# 389256 -73.998511           Entire rental unit  Entire home/apt             4
# 389257 -74.005410           Entire rental unit  Entire home/apt             2
# 389258 -73.901203  Private room in rental unit     Private room             1
#
#           price  number_of_reviews  number_of_reviews_l30d  availability_30  \
# 0       $289.00                  0                       0               30
# 1       $150.00                  0                       0                0
# 2        $55.00                  3                       0                0
# 3       $301.00                  0                       0                0
# 4       $144.00                  9                       0               29
# ...         ...                ...                     ...              ...
# 389254  $190.00                  0                       0               30
# 389255   $96.00                  0                       0               16
# 389256  $156.00                  0                       0               20
# 389257  $144.00                  0                       0               29
# 389258   $93.00                  0                       0               30
#
#         availability_60
# 0                    60
# 1                     0
# 2                     0
# 3                     0
# 4                    59
# ...                 ...
# 389254               60
# 389255               34
# 389256               50
# 389257               59
# 389258               60
#
# [389259 rows x 17 columns]

# %%
# Datetime cleanup:

# Defined potential date formats
formats = [    '%Y-%m-%d', '%Y/%m/%d', '%Y%m%d',  # ISO 8601 format with different separators
    '%d-%m-%Y', '%d/%m/%Y', '%d%m%Y',  # European date format with different separators
    '%m-%d-%Y', '%m/%d/%Y', '%m%d%Y','%Y-%m-%d', '%m/%d/%y','%M/%d/%y','%d-%m-%Y', '%Y/%m/%d', '%d/%m/%Y']  

# Loop through each potential format and return a NaN if format_ isnn't found in formats
for format_ in formats:
    df['last_scraped'] = pd.to_datetime(df['last_scraped'], format=format_, errors='coerce')
    df['host_since'] = pd.to_datetime(df['host_since'], format=format_, errors='coerce')

# Deleted dates whose format could not be identified.

df=df.dropna()

# %%
# Clean up pricing column by removing obj. characters that can't be converted into a number and concevert to floating number

# Convert obj to float for future analysis.  Because the obj has $ and ".", we need to remove them via the str.replace.
# The regex=True allows us to cobine the removal of both '$' and the ','.  If regex=False, we'd need to run a string for '$' and another for ','
# We then use the .astype to convert to float

df['price'] = df['price'].str.replace('[\$,]', '', regex=True).astype(float)
# Out:
# /var/folders/_8/bjt43fq96qv28jftlp5g3m800000gp/T/ipykernel_44482/2585978623.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'] = df['price'].str.replace('[\$,]', '', regex=True).astype(float)

# %%
print(df.isnull().sum())
# Out:
# id                              0
# last_scraped                    0
# host_id                         0
# host_since                      0
# host_listings_count             0
# neighbourhood_cleansed          0
# neighbourhood_group_cleansed    0
# latitude                        0
# longitude                       0
# property_type                   0
# room_type                       0
# accommodates                    0
# price                           0
# number_of_reviews               0
# number_of_reviews_l30d          0
# availability_30                 0
# availability_60                 0
# dtype: int64

# %%
# Confirmed data types have been correctly formatted.

df.dtypes
# Out:
# id                                     float64
# last_scraped                    datetime64[ns]
# host_id                                  int64
# host_since                      datetime64[ns]
# host_listings_count                    float64
# neighbourhood_cleansed                  object
# neighbourhood_group_cleansed            object
# latitude                               float64
# longitude                              float64
# property_type                           object
# room_type                               object
# accommodates                             int64
# price                                  float64
# number_of_reviews                        int64
# number_of_reviews_l30d                   int64
# availability_30                          int64
# availability_60                          int64
# dtype: object

# %%
df.shape
# Out:
# (345698, 17)

# %%
df.head()
# Out:
#              id last_scraped   host_id host_since  host_listings_count  \
# 0  7.434308e+17   2024-01-05  83422715 2016-07-12                  1.0
# 1  1.194300e+04   2024-01-05     45445 2009-10-12                  1.0
# 2  1.312228e+06   2024-01-05   7130382 2013-06-26                  1.0
# 3  1.344048e+07   2024-01-06  17385374 2014-06-29                  1.0
# 4  4.527754e+07   2024-01-05  51501835 2015-12-16                139.0
#
#   neighbourhood_cleansed neighbourhood_group_cleansed  latitude  longitude  \
# 0               Flatbush                     Brooklyn  40.65375  -73.95502
# 1               Flatbush                     Brooklyn  40.63702  -73.96327
# 2           Clinton Hill                     Brooklyn  40.68371  -73.96461
# 3        Upper East Side                    Manhattan  40.76550  -73.97080
# 4         Hell's Kitchen                    Manhattan  40.76661  -73.98810
#
#                  property_type        room_type  accommodates  price  \
# 0           Entire rental unit  Entire home/apt             3  289.0
# 1         Private room in home     Private room             1  150.0
# 2  Private room in rental unit     Private room             1   55.0
# 3  Private room in rental unit     Private room             1  301.0
# 4           Entire rental unit  Entire home/apt             4  144.0
#
#    number_of_reviews  number_of_reviews_l30d  availability_30  availability_60
# 0                  0                       0               30               60
# 1                  0                       0                0                0
# 2                  3                       0                0                0
# 3                  0                       0                0                0
# 4                  9                       0               29               59

# %%
df1=df.loc[df['availability_60']>0].reset_index(drop=True)
df1.shape
# Out:
# (223392, 17)

# %%
df1.head()
# Out:
#              id last_scraped    host_id host_since  host_listings_count  \
# 0  7.434308e+17   2024-01-05   83422715 2016-07-12                  1.0
# 1  4.527754e+07   2024-01-05   51501835 2015-12-16                139.0
# 2  6.550782e+17   2024-01-05   22129776 2014-10-04                 61.0
# 3  3.857863e+06   2024-01-06   19902271 2014-08-12                  2.0
# 4  1.010360e+18   2024-01-05  310205815 2019-11-17                  4.0
#
#   neighbourhood_cleansed neighbourhood_group_cleansed   latitude  longitude  \
# 0               Flatbush                     Brooklyn  40.653750 -73.955020
# 1         Hell's Kitchen                    Manhattan  40.766610 -73.988100
# 2                Midtown                    Manhattan  40.751440 -73.974930
# 3     Washington Heights                    Manhattan  40.835600 -73.942500
# 4           East Village                    Manhattan  40.724217 -73.988522
#
#                  property_type        room_type  accommodates  price  \
# 0           Entire rental unit  Entire home/apt             3  289.0
# 1           Entire rental unit  Entire home/apt             4  144.0
# 2                Room in hotel     Private room             2  449.0
# 3  Private room in rental unit     Private room             2  120.0
# 4  Private room in rental unit     Private room             2  100.0
#
#    number_of_reviews  number_of_reviews_l30d  availability_30  availability_60
# 0                  0                       0               30               60
# 1                  9                       0               29               59
# 2                  0                       0               30               60
# 3                156                       0               28               58
# 4                  0                       0               30               60

# %%
#get the average price per borough
average_price_per_borough = clean_combined_data.groupby('neighbourhood_group_cleansed')['price'].mean()
average_price_per_borough
